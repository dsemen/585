# %% [markdown]
# - 1516 и 1518 есть во всех магах, ТГ умножить на долю, минимум по 15 и 17 штук максимум 38 и 43 штуки, если норма ТГ меньше 40, то делится между этими тпг пополам
# - 1517 есть во всех магах, где норма больше или равна 40. Если норма больше 60, то ТГ умножить на долю, минимум 15 штук максимум 42, если меньше, то норма по ТГ минус сумма 1516 и 1518
# - 1519 есть во всех магах где норма больше или равна 60, ТГ умножить на долю, минимум 12 максимум 90 (включая 6 и 8, которые досыпаются вручную)
# - 1522 есть во всех магах где норма больше  59. Если меньше или равна 70, то норма ТГ минус сумма 1516 по 1519, если больше, то ТГ умножить на долю минимум 10 максимум 35
# - 1521 есть во всех магах где норма больше или равна 100 минимум 10 максимум 25
# - 1520 есть во всех магах где норма больше или равна 260 минимум 10 максимум 22
# - 1523-1533 есть во всех магах, норма ТПГ = (Норма ТГ минус сумма с 1516 по 1522) умножить на скорректированный % по тпг. Если по тпг с 1516 по 1522 норма посчитана корректно, то нормы по этим тпг появятся только, если норма по ТГ будет больше 70

# %%
import pandas as pd
import numpy as np
