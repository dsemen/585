# %%
import pandas as pd
import numpy as np
accepted = pd.read_csv('C:/рушники/задание 3_данные/accepted.csv', delimiter=';')
shown = pd.read_csv('C:/рушники/задание 3_данные/shown.csv', delimiter=';')

# %%
#пропущенные значения
accepted.info()
print('-----------------------------------')
shown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6589 entries, 0 to 6588
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PERSON_ID                      6589 non-null   object
#  1   OFFER_ACCEPTED_EVENT_OFFER_ID  6589 non-null   int64
#  2   OFFER_ACCEPTED_EVENT_VIEW_ID   6572 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 154.6+ KB
# -----------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160775 entries, 0 to 160774
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   PERSON_ID                    160775 non-null  object
#  1   OFFER_SHOWN_EVENT_ID         160775 non-null  int64
#  2   OFFER_SHOWN_EVENT_BLOCK_ID   160331 non-null  object
#  3   OFFER_SHOWN_EVENT_VIEW_ID    160775 non-null  object
# ...

# %%
#убираем строки с пропущенными значениями в OFFER_ACCEPTED_EVENT_VIEW_ID 
accepted = accepted[~accepted.OFFER_ACCEPTED_EVENT_VIEW_ID.isna()]

# %%
# сравнить уникальные значения в OFFER_SHOWN_EVENT_ID и OFFER_SHOWN_EVENT_VIEW_ID, если одинаково, то можно убрать колонку OFFER_SHOWN_EVENT_ID
len(shown.OFFER_SHOWN_EVENT_ID.unique()) - len(shown.OFFER_SHOWN_EVENT_VIEW_ID.unique())
# Out:
# 0

# %%
shown.drop(columns='OFFER_SHOWN_EVENT_ID', inplace=True)

# %%
# переименовать колонки
accepted.columns = ['PERSON_ID', 'OFFER_ID','VIEW_ID']
shown.columns = ['PERSON_ID', 'BLOCK_ID', 'VIEW_ID', 'SOURCE_ID']

# %%
# VIEW_ID из accepted, которых нет в shown
accepted[~accepted.VIEW_ID.isin(shown.VIEW_ID.tolist())]
# Out:
#                PERSON_ID  OFFER_ID                               VIEW_ID
# 104   334151391510476773      1466  4c653b4a-8956-4bdc-8922-295ec24dffb9
# 831  5664163361511462825      1055  f6075074-84fb-4eba-9838-6ed2fbfe9f23

# %%
#убираем эти строки
accepted = accepted[accepted.VIEW_ID.isin(shown.VIEW_ID.tolist())]

# %%
# пропущенные в BLOCK_ID на noblock
shown.BLOCK_ID.fillna('noblock', inplace=True)

# %%
# повторяющиеся значения в accepted
doubled = accepted[accepted.VIEW_ID.duplicated(keep=False)].sort_values(by ='VIEW_ID')
doubled
# Out:
#                 PERSON_ID  OFFER_ID                               VIEW_ID
# 4301  9901217651513016729      2222  00a2798d-62bc-4830-9ed8-1040e2327f3c
# 5108  9901217651513016729      1055  00a2798d-62bc-4830-9ed8-1040e2327f3c
# 6176  2272640761502281522      2003  01bb39c9-fb1e-4a7a-b577-6dd7d3fcdbf7
# 5424  2272640761502281522      1330  01bb39c9-fb1e-4a7a-b577-6dd7d3fcdbf7
# 4164  2272640761502281522      1278  01bb39c9-fb1e-4a7a-b577-6dd7d3fcdbf7
# ...                   ...       ...                                   ...
# 4017  1165437401502134615      1263  ff06e8f8-08a5-4a99-baa0-e56ede9d6caa
# 3932  9354725841449923644      1278  ff34200d-ca91-4a3d-aaa3-3c0e73b65591
# 3529  9354725841449923644      1336  ff34200d-ca91-4a3d-aaa3-3c0e73b65591
# 5346  9354725841449923644      1265  ff34200d-ca91-4a3d-aaa3-3c0e73b65591
# 3480  9354725841449923644      2222  ff34200d-ca91-4a3d-aaa3-3c0e73b65591
#
# [1096 rows x 3 columns]

# %%
doubled_df = doubled.merge(shown[['BLOCK_ID', 'SOURCE_ID','VIEW_ID']], how='left', on='VIEW_ID')
doubled_df.groupby(['SOURCE_ID', 'BLOCK_ID'])['VIEW_ID'].count()
# Out:
# SOURCE_ID  BLOCK_ID
# 2          payments_external    875
#            payments_internal     14
#            promo                 36
# 3          payments_external     34
# 4          payments_external    133
#            promo                  4
# Name: VIEW_ID, dtype: int64

# %%
# есть ли повторяющиеся OFFER_ID+VIEW_ID
(doubled['OFFER_ID'].astype('str') + doubled['VIEW_ID']).duplicated().sum()
# Out:
# 0

# %%
# задублированные значение в shown
shown[shown.EVENT_VIEW_ID.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PERSON_ID, EVENT_ID, EVENT_BLOCK_ID, EVENT_VIEW_ID, EVENT_SOURCE_ID]
# Index: []

# %%
# виды количество офферов
off = accepted.OFFER_ID.unique()
print(off)
print(len(off))
# Out:
# [1578 1289 2003 1446 1069 1423 1254 1466 1055 1278 2222 1330 1574 2216
#  1067 1066 1063 1265 1103 2165 1424 2195 1487 1401 1575 1671 1245 1394
#  1336 1043 1260 1114 1325 1110 1288 1960 1068 2244 2239 2154 2004 1086
#  1408 1454 1108 2152 1469 1963 1576 1274 2234 1301 1128 2223 2227 1271
#  2186 2226 1235 1311 1304 1273 1332 1253 1322 1393 1419 1300 2164 1317
#  1105 1925 2217 1456 1944 1263 1409 1266 1376 1455 2250 1948 1232 1292
#  1256 1368]
# 86

# %%
full = shown.merge(accepted.drop(columns='PERSON_ID'), how='left', on='VIEW_ID')

# %%
full[full.VIEW_ID == '00a2798d-62bc-4830-9ed8-1040e2327f3c']
# Out:
#                  PERSON_ID           BLOCK_ID  \
# 79773  9901217651513016729  payments_external
# 79774  9901217651513016729  payments_external
#
#                                     VIEW_ID  SOURCE_ID  OFFER_ID
# 79773  00a2798d-62bc-4830-9ed8-1040e2327f3c          2    2222.0
# 79774  00a2798d-62bc-4830-9ed8-1040e2327f3c          2    1055.0

# %%
print('при SOURCE_ID = 5,  BLOCK_ID и OFFER_ID пустые')
print("\n")
full[full.SOURCE_ID == 5].info()
# Out:
# при SOURCE_ID = 5,  BLOCK_ID и OFFER_ID пустые
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 14 to 160944
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PERSON_ID  444 non-null    object
#  1   BLOCK_ID   0 non-null      object
#  2   VIEW_ID    444 non-null    object
#  3   SOURCE_ID  444 non-null    int64
#  4   OFFER_ID   0 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 20.8+ KB

# %%
# все значения PERSON_ID в блоке app_android_wallet и наоборот

print(full.PERSON_ID[full.BLOCK_ID == 'app_android_wallet'].unique())
print(full.BLOCK_ID[full.PERSON_ID == 'NULL'].unique())
# Out:
# ['NULL']
# ['app_android_wallet' nan]

# %%
full
# Out:
#                   PERSON_ID            BLOCK_ID  \
# 0       2054386841495461375   payments_external
# 1       3764008861513384289   payments_external
# 2                      NULL  app_android_wallet
# 3        819786141512056331   payments_external
# 4       4726916481493837317   payments_external
# ...                     ...                 ...
# 161478  7801314791499944588   payments_external
# 161479  1312917891513380034   payments_external
# 161480   952037551505545423   payments_external
# 161481                 NULL  app_android_wallet
# 161482  1406970231512502727   payments_external
#
#                                      VIEW_ID  SOURCE_ID  OFFER_ID
# 0       d2ab28e9-aa6e-4bcc-82a4-54223d9218fd          4       NaN
# 1       bac70f22-0855-4d08-9a96-af35b5dde76f          4       NaN
# 2       d8d63edf-7e76-459b-86f8-532292b314f6          1       NaN
# 3       e49262dc-3261-4d92-a249-1b499d375936          2       NaN
# ...

# %%
#  уникальных PERSON_ID
len(full.PERSON_ID.unique())
# Out:
# 92373

# %%
#колонка с акцептацией оффера
shown['accepted'] = shown.VIEW_ID.isin(accepted.VIEW_ID).astype('int')

# %%
quest1 = shown.groupby(['SOURCE_ID', 'BLOCK_ID'])['accepted'].aggregate(['count', 'sum'])
quest1.columns = ['показов', 'акцептов']
quest1['% акцептов'] = (quest1.акцептов / quest1.показов * 100).round(1).astype('str') + '%'
quest1.reset_index()
# Out:
#     SOURCE_ID            BLOCK_ID  показов  акцептов % акцептов
# 0           1  app_android_wallet     5971       752      12.6%
# 1           2   payments_external    93606      3931       4.2%
# 2           2   payments_internal     7462        90       1.2%
# 3           2               promo     4693        85       1.8%
# 4           3   payments_external     4182       155       3.7%
# 5           3   payments_internal      224         7       3.1%
# 6           3               promo      121         3       2.5%
# 7           4   payments_external    42212       811       1.9%
# 8           4   payments_internal     1262        15       1.2%
# 9           4               promo      598        13       2.2%
# 10          5             noblock      444         0       0.0%

# %%
shown.groupby(['SOURCE_ID', 'BLOCK_ID'])['accepted'].aggregate(['count', 'sum'])

# %%
def percent(df):
    df['% акцептов'] = (df.акцептов / df.показов * 100).round(1).astype('str') + '%'
    
temp1 = quest1.groupby('SOURCE_ID').aggregate('sum')
temp2 = quest1.groupby('BLOCK_ID').aggregate('sum')

percent(temp1)
percent(temp2)
temp1.reset_index()
# Out:
#    SOURCE_ID  показов  акцептов % акцептов
# 0          1     5971       752      12.6%
# 1          2   105761      4106       3.9%
# 2          3     4527       165       3.6%
# 3          4    44072       839       1.9%
# 4          5      444         0       0.0%

# %%
temp2.reset_index().sort_values('% акцептов',ascending=False)
# Out:
#              BLOCK_ID  показов  акцептов % акцептов
# 2   payments_external   140000      4897       3.5%
# 0  app_android_wallet     5971       752      12.6%
# 4               promo     5412       101       1.9%
# 3   payments_internal     8948       112       1.3%
# 1             noblock      444         0       0.0%

# %%
#список, кто акцептировал на  Payments_external
pext_lst = shown.PERSON_ID[(shown.BLOCK_ID == 'payments_external') & (shown.accepted == 1)].unique()

#список, кто акцептировал два раза и один на Payments_external
acc_counts = accepted.PERSON_ID.value_counts() 
accepted_lst = np.intersect1d(acc_counts[acc_counts > 2].index.values, pext_lst)
                              
# показы на более чем одном sourсe_ID
source_counts = shown.groupby(['PERSON_ID','SOURCE_ID'])['VIEW_ID'].count().unstack().count(axis=1, numeric_only=True)
source_lst = source_counts[source_counts > 1].index.values
                              
#пересечение
intersect = np.intersect1d(accepted_lst, source_lst)
intersect
# Out:
# array([], dtype=object)

# %%
dummy_df = pd.get_dummies(shown.drop(columns='VIEW_ID'), columns=['BLOCK_ID', 'SOURCE_ID', 'accepted'])
dummy_df
# Out:
#                   PERSON_ID  BLOCK_ID_app_android_wallet  BLOCK_ID_noblock  \
# 0       2054386841495461375                            0                 0
# 1       3764008861513384289                            0                 0
# 2                      NULL                            1                 0
# 3        819786141512056331                            0                 0
# 4       4726916481493837317                            0                 0
# ...                     ...                          ...               ...
# 160770  7801314791499944588                            0                 0
# 160771  1312917891513380034                            0                 0
# 160772   952037551505545423                            0                 0
# 160773                 NULL                            1                 0
# 160774  1406970231512502727                            0                 0
#
#         BLOCK_ID_payments_external  BLOCK_ID_payments_internal  \
# ...

# %%
grouped_dummy = dummy_df.groupby('PERSON_ID').sum()
grouped_dummy.reset_index(inplace=True)

# %%
# людей, которые сделали более двух акцептов, как минимум 1 из которых был на Payments_external
grouped_dummy[(grouped_dummy['accepted_1'] > 2) & (grouped_dummy['BLOCK_ID_payments_external'] > 0)]
# Out:
#                  PERSON_ID  BLOCK_ID_app_android_wallet  BLOCK_ID_noblock  \
# 1595   1129064641449506302                          0.0               0.0
# 4062   1323247121502669344                          0.0               0.0
# 4229   1336870511513347943                          0.0               0.0
# 6641   1537272081511776353                          0.0               0.0
# 7014   1568271341441865549                          0.0               0.0
# ...                    ...                          ...               ...
# 83168  9063477481511509908                          0.0               0.0
# 84988  9255717521489071425                          0.0               0.0
# 88306  9590153511512778793                          0.0               0.0
# 90944  9855049951478106991                          0.0               0.0
# 91978  9958937741513416248                          0.0               0.0
#
#        BLOCK_ID_payments_external  BLOCK_ID_payments_internal  BLOCK_ID_promo  \
# ...

# %%
#  при этом у кого были показы на более чем одном sourсe_ID
src = [x for x in grouped_dummy.columns if 'SOURCE' in x]
len(grouped_dummy.PERSON_ID[grouped_dummy[src].gt(0).sum(axis=1) > 1].values)
# Out:
# 46

# %%
grouped_dummy['acc_sum'] = grouped_dummy[['accepted_0','accepted_1']].sum(axis=1)
grouped_dummy[['accepted_0','accepted_1', 'acc_sum']]
# Out:
#        accepted_0  accepted_1  acc_sum
# 0             2.0         0.0      2.0
# 1             0.0         1.0      1.0
# 2             5.0         0.0      5.0
# 3             1.0         0.0      1.0
# 4             1.0         0.0      1.0
# ...           ...         ...      ...
# 92368         1.0         0.0      1.0
# 92369         3.0         0.0      3.0
# 92370         3.0         0.0      3.0
# 92371         1.0         0.0      1.0
# 92372      5663.0       752.0   6415.0
#
# [92373 rows x 3 columns]

# %%
grouped_dummy.accepted_1[grouped_dummy.accepted_1 > 0 grouped_dummy.accepted_1 < 500].hist(bins=5)

# %%
grouped_dummy.accepted_0[grouped_dummy.accepted_0 < 60].hist(bins=5)

# %%
grouped_dummy.accepted_1.value_counts()
# Out:
# 0.0      87766
# 1.0       4213
# 2.0        307
# 3.0         66
# 4.0         15
# 5.0          5
# 752.0        1
# Name: accepted_1, dtype: int64

# %%
grouped_dummy.accepted_0.value_counts()
# Out:
# 1.0       62066
# 2.0       15503
# 3.0        5529
# 0.0        2873
# 4.0        2628
# 5.0        1404
# 6.0         786
# 7.0         447
# 8.0         306
# 9.0         202
# 10.0        135
# 11.0         87
# 12.0         80
# 13.0         67
# 14.0         40
# 15.0         39
# 16.0         20
# 17.0         18
# 19.0         17
# 20.0         16
# 18.0         11
# 26.0          9
# 25.0          8
# 24.0          8
# 23.0          8
# 21.0          7
# 22.0          6
# 27.0          5
# 29.0          4
# 32.0          3
# 30.0          3
# 34.0          3
# 33.0          3
# 28.0          3
# 43.0          2
# 61.0          2
# 36.0          2
# 37.0          2
# 40.0          2
# 31.0          2
# 41.0          1
# 56.0          1
# 79.0          1
# 35.0          1
# 95.0          1
# 44.0          1
# 48.0          1
# 42.0          1
# 55.0          1
# 38.0          1
# 53.0          1
# 5663.0        1
# 89.0          1
# 74.0          1
# 45.0          1
# ...

# %%
grouped_dummy[['accepted_0','accepted_1']].sum(axis=1).value_counts()
# Out:
# 1.0       63723
# 2.0       16217
# 3.0        5776
# 4.0        2775
# 5.0        1461
# 6.0         806
# 7.0         451
# 8.0         319
# 9.0         207
# 10.0        134
# 11.0         92
# 12.0         82
# 13.0         70
# 15.0         40
# 14.0         39
# 17.0         19
# 16.0         19
# 19.0         17
# 20.0         15
# 18.0         11
# 26.0         10
# 24.0          9
# 21.0          8
# 23.0          7
# 25.0          7
# 22.0          6
# 27.0          5
# 29.0          4
# 34.0          4
# 30.0          3
# 32.0          3
# 28.0          3
# 31.0          2
# 37.0          2
# 43.0          2
# 40.0          2
# 61.0          2
# 36.0          2
# 33.0          2
# 42.0          1
# 56.0          1
# 48.0          1
# 51.0          1
# 45.0          1
# 41.0          1
# 44.0          1
# 74.0          1
# 79.0          1
# 95.0          1
# 89.0          1
# 55.0          1
# 6415.0        1
# 38.0          1
# 53.0          1
# 35.0          1
# ...

# %%
import matplotlib.pyplot as plt

# %%
quest1.reset_index(inplace=True)
quest1
# Out:
#     index  SOURCE_ID            BLOCK_ID  показов  акцептов % акцептов
# 0       0          1  app_android_wallet     5971       752      12.6%
# 1       1          2   payments_external    93606      3931       4.2%
# 2       2          2   payments_internal     7462        90       1.2%
# 3       3          2               promo     4693        85       1.8%
# 4       4          3   payments_external     4182       155       3.7%
# 5       5          3   payments_internal      224         7       3.1%
# 6       6          3               promo      121         3       2.5%
# 7       7          4   payments_external    42212       811       1.9%
# 8       8          4   payments_internal     1262        15       1.2%
# 9       9          4               promo      598        13       2.2%
# 10     10          5             noblock      444         0       0.0%

# %%
plt.scatter(quest1.BLOCK_ID, quest1.SOURCE_ID,
             s=quest1.акцептов)
plt.xlabel("X", size=16)
plt.ylabel("y", size=16)
plt.title("Bubble Plot with Colors: Matplotlib", size=18)
plt.figsize(10,20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-374-9c46694ed924> in <module>()
#       4 plt.ylabel("y", size=16)
#       5 plt.title("Bubble Plot with Colors: Matplotlib", size=18)
# ----> 6 plt.figsize(10,20)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'figsize'

# %%
plt.scatter(quest1.BLOCK_ID, quest1.SOURCE_ID,
             s=quest1.показов,
             c='Colors',
             alpha=0.5, data=df)
plt.xlabel("X", size=16)
plt.ylabel("y", size=16)
plt.title("Bubble Plot with Colors: Matplotlib", size=18)
